# %% [markdown]
# ## **HR Employee Attrition**

# %% [markdown]
# This is a fictional dataset created by IBM Data Scientists to analyze the factors of employee attrition. However, we do not know much about the fields that were generated. So, we will do an EDA before exporting this dataset to visualize it in Looker Studio.

# %% [markdown]
# First we import the main libraries and the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
employee_df = pd.read_csv('./HR_employee_attrition.csv')
employee_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Dataset Dimensions
# Rows = 1,470
# Columns = 35

employee_df.shape
# Out:
# (1470, 35)

# %%
employee_df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
(employee_df.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
employee_df.dropna().shape
# Out:
# (1470, 35)

# %% [markdown]
# After the first look, we can see that this dataset contains 1,470 rows and 35 columns. Each variable shows a specific characteristic of the company's employees. Regarding the data values, there are no nulls and there is a wide range of categorical and continuous variables. Now we will explore the distribution of each variable.

# %%
employee_df.hist(figsize=(18,18))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'Education'}>,
#         <Axes: title={'center': 'EmployeeCount'}>],
#        [<Axes: title={'center': 'EmployeeNumber'}>,
#         <Axes: title={'center': 'EnvironmentSatisfaction'}>,
#         <Axes: title={'center': 'HourlyRate'}>,
#         <Axes: title={'center': 'JobInvolvement'}>,
#         <Axes: title={'center': 'JobLevel'}>],
#        [<Axes: title={'center': 'JobSatisfaction'}>,
#         <Axes: title={'center': 'MonthlyIncome'}>,
#         <Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>,
#         <Axes: title={'center': 'PercentSalaryHike'}>],
#        [<Axes: title={'center': 'PerformanceRating'}>,
#         <Axes: title={'center': 'RelationshipSatisfaction'}>,
#         <Axes: title={'center': 'StandardHours'}>,
# ...

# %% [markdown]
# This is interesting. The *age* variable almost looks like it is Normal Distributed, but it is a little skewed to the right. However, the same does not apply to the rest of the variables. Columns like the *distance from home*, the *years at the company* or the *monthly income* are distributions very skewed to the right.
#
# Also, we can identify very clearly the distributions of the categorical values, like *work-life balance*, or the *employees' education*. Finally, the *hours rates* and *month rates* appear to follow a uniform distribution, which shows that there is almost the same amount of employees in each rate interval.

# %% [markdown]
# We will have a closer look to the age variable. We can analyze if it actually follows a Normal Distribution or not. Apart from being something nice to know, it would be useful if we were to make a model with our data and if we had to make assumptions about the distribution of the variable.

# %%
employee_df['Age'].hist(figsize=(4,4))
# Out:
# <Axes: >

# %%
age_mean = employee_df['Age'].mean()
age_std = employee_df['Age'].std()

print(age_mean, age_std)
# Out:
# 36.923809523809524 9.135373489136734

# %% [markdown]
# We know the mean and the standard deviation of the distribution. Now, in order to check if this ressembles a normal distribution, we have to know if this follows the impirical rule:
#
# 1. 68% of values fall within 1 standard deviation of the mean
# 1. 95% of values fall within 2 standard deviation of the mean
# 1. 99.7% of values fall within 3 standard deviation of the mean

# %%
values = {}

for i in range(1,4):
    lower_limit = age_mean - i * age_std
    upper_limit = age_mean + 1 * age_std

    result = ((employee_df['Age'] >= lower_limit) & (employee_df['Age'] <= upper_limit)).mean()

    if i not in values:
        values[i] = [result]
    else: 
        values[i].append(result)

values
# Out:
# {1: [0.6938775510204082], 2: [0.8312925170068027], 3: [0.8367346938775511]}

# %% [markdown]
# **Conclusion**: As similar as the distribution may look, the data does not support that the Age follows a Normal Distribution.

# %% [markdown]
# ### **Data Relationships**
# Now that we have explored the data, it is time to analyze what are the relationships that we will visualize in the Looker Studio. The main objective is to study the Attrition of these employees.

# %%
employee_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# First, we need to see how many employees left the company in general

# %%
plt.bar(employee_df['Attrition'].unique(), employee_df['Attrition'].value_counts(), color = ['red', 'green'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# Apparently, there are more people inside this dataset that left the company, than people that did not. Now, we will analyze wether there are any strong relationships between Attrition and other employees' characteristics.

# %%
# We define a target variable to correlate aginst the rest:

target_variable = 'Attrition'

# %%
# Then, we have to re-map the existing variables to their corresponding values. For example, Education or Environment Satisfaction

# Maps
mapping_education = {1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'}
mapping_env_satisfaction = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
mapping_job_involvement = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
mapping_job_satisfaction = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
mapping_performance = {1: 'Low', 2: 'Good', 3: 'Excellent', 4: 'Outstanding'}
mapping_relationship = {1: 'Low', 2: 'Good', 3: 'High', 4: 'Very High'}
mapping_work_balance = {1: 'Bad', 2: 'Good', 3: 'Better', 4: 'Best'}

# Re-mapping
employee_df['Education'] = employee_df['Education'].map(mapping_education)
employee_df['EnvironmentSatisfaction'] = employee_df['EnvironmentSatisfaction'].map(mapping_env_satisfaction)
employee_df['JobInvolvement'] = employee_df['JobInvolvement'].map(mapping_job_involvement)
employee_df['JobSatisfaction'] = employee_df['JobSatisfaction'].map(mapping_job_satisfaction)
employee_df['PerformanceRating'] = employee_df['PerformanceRating'].map(mapping_performance)
employee_df['RelationshipSatisfaction'] = employee_df['RelationshipSatisfaction'].map(mapping_relationship)
employee_df['WorkLifeBalance'] = employee_df['WorkLifeBalance'].map(mapping_work_balance)

# %%
employee_df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# ...

# %%
palette = {'Yes': 'blue', 'No': 'red'}

# %%
for i, col in enumerate(employee_df.drop(['Attrition','EmployeeCount','EmployeeNumber','HourlyRate','MonthlyRate', 'MonthlyIncome', 'DailyRate'], axis=1).columns):
    plt.figure(i,figsize=(12,4))
    sns.countplot(x=col, 
                  hue='Attrition', 
                  data=employee_df, 
                  hue_order=['Yes','No'], 
                  palette=['red','green']);
# Out:
# /var/folders/pq/1m76547d2jz0k_pfwwl11pqm0000gn/T/ipykernel_20385/3180488230.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(i,figsize=(12,4))

# %% [markdown]
# Finally, we will see the MonthlyIncome distribution between the employees that left the company and the ones that did not

# %%
NoAttrition = employee_df[employee_df['Attrition'] == 'No']
NoAttrition.head()
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0    41       Yes  Travel_Rarely       1102                   Sales
# 2    37       Yes  Travel_Rarely       1373  Research & Development
# 14   28       Yes  Travel_Rarely        103  Research & Development
# 21   36       Yes  Travel_Rarely       1218                   Sales
# 24   34       Yes  Travel_Rarely        699  Research & Development
#
#     DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                  1        College  Life Sciences              1
# 2                  2        College          Other              1
# 14                24       Bachelor  Life Sciences              1
# 21                 9         Master  Life Sciences              1
# 24                 6  Below College        Medical              1
#
#     EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 0                1  ...                      Low            80
# ...

# %%
YesAttrition = employee_df[employee_df['Attrition'] == 'Yes']
YesAttrition.head()
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0    41       Yes  Travel_Rarely       1102                   Sales
# 2    37       Yes  Travel_Rarely       1373  Research & Development
# 14   28       Yes  Travel_Rarely        103  Research & Development
# 21   36       Yes  Travel_Rarely       1218                   Sales
# 24   34       Yes  Travel_Rarely        699  Research & Development
#
#     DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                  1        College  Life Sciences              1
# 2                  2        College          Other              1
# 14                24       Bachelor  Life Sciences              1
# 21                 9         Master  Life Sciences              1
# 24                 6  Below College        Medical              1
#
#     EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 0                1  ...                      Low            80
# ...

# %%
NoAttrition['MonthlyIncome'].hist(figsize=(6,6))
# Out:
# <Axes: >

# %%
YesAttrition['MonthlyIncome'].hist(figsize=(6,6))
# Out:
# <Axes: >

# %% [markdown]
# ### **Conclusions**

# %% [markdown]
# There are certaing variables that really stand out when analyzing the employees' attrition, which will be the main variables used when exporting this dataset to a Looker Studio. The graphs above show that there is a higher attrition among employees with low:
# 1. Percent of salary hikes
# 1. Years at the company
# 1. Years in their current role
# 1. Years working in general
# 1. Age (below 30 years-old)
# 1. Stock options
#
# So, in general, **younger employees** tend to be more prone to leave the company. This clearly is something expectable, as the younger generations tend to rotate their jobs much more then the previous generations. This in fact has allowed them to scale a little bit easier, but of course it depends on each employee. For that same reason, the job of an HR area is to ensure that the job perception of the company employees is always high, which at the same time implies that they receive additional benefits like quarterly bonuses, options for education, options to grow at the company, and visually signs that they care their perception of the company.
